# %%
from pathlib import Path
from src.data_utils.preprocessing import (
    PreprocessingConfig,
    prepare_train_test_split,
)

config = PreprocessingConfig(
    # adjust if your column names differ
    date_col="Date",
    store_col="Store",
    target_col="Sales",
    lags=(1, 7, 14, 28, 365),
)

# %%
train_scaled, test_scaled, x_scaler, y_scaler = prepare_train_test_split(
    train_path=Path("data/train.csv"),
    store_path=Path("data/store.csv"),
    config=config,
    # optional overrides:
    # lagged_cols=["Sales", "Customers"],
    # numeric_cols=["sqrt_Sales", "CompetitionDistance", ...],
)
# Out:
# d:\FIU\CAP 3764 Advanced Data Science\CAP_3764_2025_Fall_Team_2\src\data_utils\preprocessing.py:78: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(Path(path))

# %%
train_scaled.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'Competition_open_since_August',
#        'Competition_open_since_December', 'Competition_open_since_February',
#        'Competition_open_since_January', 'Competition_open_since_July',
#        'Competition_open_since_June', 'Competition_open_since_March',
#        'Competition_open_since_May', 'Competition_open_since_November',
#        'Competition_open_since_October', 'Competition_open_since_September',
#        'Promo2_Interval_in_Aug', 'Promo2_Interval_in_Dec',
#        'Promo2_Interval_in_Feb', 'Promo2_Interval_in_Jan',
#        'Promo2_Interval_in_Jul', 'Promo2_Interval_in_Jun',
#        'Promo2_Interval_in_Mar', 'Promo2_Interval_in_May',
#        'Promo2_Interval_in_Nov', 'Promo2_Interval_in_Oct',
# ...

# %%
test_scaled.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'Competition_open_since_August',
#        'Competition_open_since_December', 'Competition_open_since_February',
#        'Competition_open_since_January', 'Competition_open_since_July',
#        'Competition_open_since_June', 'Competition_open_since_March',
#        'Competition_open_since_May', 'Competition_open_since_November',
#        'Competition_open_since_October', 'Competition_open_since_September',
#        'Promo2_Interval_in_Aug', 'Promo2_Interval_in_Dec',
#        'Promo2_Interval_in_Feb', 'Promo2_Interval_in_Jan',
#        'Promo2_Interval_in_Jul', 'Promo2_Interval_in_Jun',
#        'Promo2_Interval_in_Mar', 'Promo2_Interval_in_May',
#        'Promo2_Interval_in_Nov', 'Promo2_Interval_in_Oct',
# ...

# %%
# train_scaled/test_scaled are ready for modeling; target is scaled if present
X_train = train_scaled.drop(columns=[config.target_col])
y_train = train_scaled[config.target_col]

X_test = test_scaled.drop(columns=[config.target_col])
y_test = test_scaled[config.target_col]
